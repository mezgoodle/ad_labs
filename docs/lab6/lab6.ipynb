# %% [markdown]
# <a href="https://colab.research.google.com/github/mezgoodle/ad_labs/blob/master/docs/lab6/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Вступ

# %% [markdown]
# Створити програму, яка виконує наступні завдання, використовуючи файл
# відповідно до варіанту:
#
# 1. Читає файл та змінює назви стовпців.
#
# 2. Виконує попередню обробку даних.

# %% [markdown]
# Варіант 7: Version 7.xlsx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Дані

# %%
df = pd.read_excel('https://raw.githubusercontent.com/mezgoodle/ad_labs/master/data/Version_7.xlsx', header=[0, 1])
df.head(5)
# Out:
#   Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                 Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 0         2009-07-21            1.483  ...                  NaN           NaN
# 1         2009-08-05            1.102  ...                223.0         194.0
# 2         2009-08-19            0.638  ...                231.0         180.0
# 3         2009-09-02            0.744  ...                237.0         171.0
# 4         2009-09-16            1.362  ...                240.0         165.0
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Unnamed: 0_level_0, Date)                    58 non-null     datetime64[ns]
#  1   (Phytoplankton, Biovolume, mm3/L)             58 non-null     float64
#  2   (Phytoplankton, Biovolume, mm3/L.1)           0 non-null      float64
#  3   (Zooplankton, Biomass, g d.w./m2)             58 non-null     float64
#  4   (Zooplankton, Biomass, g d.w./m2.1)           0 non-null      float64
#  5   (Zooplankton, Chl a, µg/L)                    52 non-null     float64
#  6   (Mean Crustacean, Length, mm)                 58 non-null     object
#  7   (Mean Crustacean, NH4,mg/L as N)              58 non-null     float64
#  8   (Mean Crustacean, Nox,mg/L as N)              57 non-null     float64
# ...

# %%
df.columns
# Out:
# MultiIndex([(     'Unnamed: 0_level_0',                 'Date'),
#             (          'Phytoplankton',     'Biovolume, mm3/L'),
#             (          'Phytoplankton',   'Biovolume, mm3/L.1'),
#             (            'Zooplankton',   'Biomass, g d.w./m2'),
#             (            'Zooplankton', 'Biomass, g d.w./m2.1'),
#             (            'Zooplankton',          'Chl a, µg/L'),
#             (        'Mean Crustacean',           'Length, mm'),
#             (        'Mean Crustacean',        'NH4,mg/L as N'),
#             (        'Mean Crustacean',        'Nox,mg/L as N'),
#             ('NUTRIENT CONCENTRATIONS',        'FRP,mg/L as P'),
#             ('NUTRIENT CONCENTRATIONS',    'Total N,mg/L as N'),
#             ('NUTRIENT CONCENTRATIONS',         'Total P,mg/L'),
#             ('NUTRIENT CONCENTRATIONS',             'Secchi,m'),
#             ('NUTRIENT CONCENTRATIONS',           'pH at 0.5m'),
# ...

# %% [markdown]
# # Видалення дублікатів дати

# %%
df[("Unnamed: 0_level_0", "Date")].duplicated().value_counts()
# Out:
# False    50
# True      8
# Name: (Unnamed: 0_level_0, Date), dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df[("Unnamed: 0_level_0", "Date")].duplicated().value_counts()
# Out:
# False    50
# True      3
# Name: (Unnamed: 0_level_0, Date), dtype: int64

# %%
df[("Unnamed: 0_level_0", "Date")].value_counts()
# Out:
# 2010-04-20    2
# 2010-02-19    2
# 2011-03-30    2
# 2009-10-02    1
# 2011-06-08    1
# 2010-12-30    1
# 2010-06-02    1
# 2011-03-02    1
# 2011-06-22    1
# 2010-11-03    1
# 2010-07-14    1
# 2009-08-05    1
# 2009-11-25    1
# 2010-06-30    1
# 2010-12-15    1
# 2009-10-27    1
# 2010-03-24    1
# 2009-08-19    1
# 2010-08-12    1
# 2011-02-02    1
# 2011-05-25    1
# 2010-08-25    1
# 2009-11-11    1
# 2011-05-11    1
# 2011-02-18    1
# 2010-04-07    1
# 2010-02-03    1
# 2010-10-05    1
# 2011-04-27    1
# 2010-11-16    1
# 2010-07-28    1
# 2010-05-19    1
# 2009-12-08    1
# 2010-10-20    1
# 2010-01-20    1
# 2011-04-13    1
# 2010-05-05    1
# 2009-10-14    1
# 2010-06-17    1
# 2011-01-12    1
# 2010-01-06    1
# 2009-09-16    1
# 2011-01-20    1
# 2010-12-01    1
# 2009-07-21    1
# 2010-03-10    1
# 2009-09-02    1
# 2009-12-23    1
# 2011-03-16    1
# 2010-09-22    1
# Name: (Unnamed: 0_level_0, Date), dtype: int64

# %%
df[df[("Unnamed: 0_level_0", "Date")] == '2010-04-20']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 20         2010-04-20            0.288  ...                264.0         344.0
# 21         2010-04-20            0.288  ...                264.0         344.0
#
# [2 rows x 17 columns]

# %%
index_value = df[df[("Unnamed: 0_level_0", "Date")] == '2010-04-20'].index
df.drop(index_value[0], inplace=True)
df[df[("Unnamed: 0_level_0", "Date")] == '2010-04-20']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 21         2010-04-20            0.288  ...                264.0         344.0
#
# [1 rows x 17 columns]

# %%
df[df[("Unnamed: 0_level_0", "Date")] == '2010-02-19']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 15         2010-02-19            26.79  ...                307.0         380.0
# 16         2010-02-19            26.79  ...                307.0         380.0
#
# [2 rows x 17 columns]

# %%
index_value = df[df[("Unnamed: 0_level_0", "Date")] == '2010-02-19'].index
df.drop(index_value[0], inplace=True)
df[df[("Unnamed: 0_level_0", "Date")] == '2010-02-19']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 16         2010-02-19            26.79  ...                307.0         380.0
#
# [1 rows x 17 columns]

# %%
df[df[("Unnamed: 0_level_0", "Date")] == '2011-03-30']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 42         2011-03-30            40.58  ...                228.0         380.0
# 51         2011-03-30            40.58  ...                228.0         380.0
#
# [2 rows x 17 columns]

# %%
index_value = df[df[("Unnamed: 0_level_0", "Date")] == '2011-03-30'].index
df.drop(index_value[1], inplace=True)
df[df[("Unnamed: 0_level_0", "Date")] == '2011-03-30']
# Out:
#    Unnamed: 0_level_0    Phytoplankton  ...          Mean column
#                  Date Biovolume, mm3/L  ... Conductivity,µS cm-1 Turbidity,NTU
# 42         2011-03-30            40.58  ...                228.0         380.0
#
# [1 rows x 17 columns]

# %% [markdown]
# # Перетворення типів даних

# %%
df.loc[:, :].replace("?", np.nan, inplace=True)
df[("Mean Crustacean", "Length, mm")].astype(float)
df[("Mean Crustacean", "Length, mm")].describe()
# Out:
# count      50.000000
# mean       20.653000
# std       141.327197
# min         0.369000
# 25%         0.567250
# 50%         0.660500
# 75%         0.768750
# max      1000.000000
# Name: (Mean Crustacean, Length, mm), dtype: float64

# %% [markdown]
# # Обробка нульових значень

# %%
df.isnull().sum(axis=0) / df.shape[0]
# Out:
# Unnamed: 0_level_0       Date                    0.00
# Phytoplankton            Biovolume, mm3/L        0.00
#                          Biovolume, mm3/L.1      1.00
# Zooplankton              Biomass, g d.w./m2      0.00
#                          Biomass, g d.w./m2.1    1.00
#                          Chl a, µg/L             0.10
# Mean Crustacean          Length, mm              0.00
#                          NH4,mg/L as N           0.00
#                          Nox,mg/L as N           0.00
# NUTRIENT CONCENTRATIONS  FRP,mg/L as P           0.00
#                          Total N,mg/L as N       0.00
#                          Total P,mg/L            0.00
#                          Secchi,m                0.00
#                          pH at 0.5m              0.02
#                          Mean column toC         0.02
# Mean column              Conductivity,µS cm-1    0.02
#                          Turbidity,NTU           0.02
# dtype: float64

# %%
df.drop([("Zooplankton", "Biomass, g d.w./m2.1"), ("Phytoplankton", "Biovolume, mm3/L.1")], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 57
# Data columns (total 15 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   (Unnamed: 0_level_0, Date)                    50 non-null     datetime64[ns]
#  1   (Phytoplankton, Biovolume, mm3/L)             50 non-null     float64
#  2   (Zooplankton, Biomass, g d.w./m2)             50 non-null     float64
#  3   (Zooplankton, Chl a, µg/L)                    45 non-null     float64
#  4   (Mean Crustacean, Length, mm)                 50 non-null     float64
#  5   (Mean Crustacean, NH4,mg/L as N)              50 non-null     float64
#  6   (Mean Crustacean, Nox,mg/L as N)              50 non-null     float64
#  7   (NUTRIENT CONCENTRATIONS, FRP,mg/L as P)      50 non-null     float64
#  8   (NUTRIENT CONCENTRATIONS, Total N,mg/L as N)  50 non-null     float64
# ...

# %%
df.columns=['date', 'phyto_biov', 'zoo_biom', 'zoo_chl', 'crusta_lenght_mean', 
            'crusta_nh4_mean', 'crusta_nox_mean', 'nutrient_frp', 
            'nutrient_total_n', 'nutrient_total_p', 'nutrient_secchi',
            'nutrient_ph', 'nutrient_mean', 'conductivity_mean',
            'turbidity_mean']

# %% [markdown]
# # Сортування даних та встановлення індексу

# %%
df.sort_values(by='date', inplace=True)

# %%
df.set_index('date', inplace=True)

# %%
df.describe().T
# Out:
#                     count        mean  ...        75%       max
# phyto_biov           50.0    7.809460  ...    4.56325   107.520
# zoo_biom             50.0    0.341196  ...    0.29975     4.436
# zoo_chl              45.0   14.177778  ...   19.00000    90.000
# crusta_lenght_mean   50.0   20.653000  ...    0.76875  1000.000
# crusta_nh4_mean      50.0    0.017060  ...    0.01475     0.190
# crusta_nox_mean      50.0    0.321520  ...    0.52750     0.630
# nutrient_frp         50.0    0.164060  ...    0.19750     0.260
# nutrient_total_n     50.0    1.550000  ...    1.80000     3.200
# nutrient_total_p     50.0    0.372200  ...    0.43000     0.480
# nutrient_secchi      50.0    0.130600  ...    0.15000     0.200
# nutrient_ph          49.0    7.597551  ...    7.80000     9.000
# nutrient_mean        49.0   20.702041  ...   24.30000    26.700
# conductivity_mean    49.0  253.959184  ...  269.00000   312.000
# turbidity_mean       49.0  321.775510  ...  377.00000   415.000
#
# ...

# %% [markdown]
# # Зміна надвисоких значень

# %%
df.phyto_biov = df.phyto_biov.replace(107.520, np.nan)
df.crusta_lenght_mean = df.crusta_lenght_mean.replace(1000, np.nan)

# %%
df
# Out:
#             phyto_biov  zoo_biom  ...  conductivity_mean  turbidity_mean
# date                              ...
# 2009-07-21       1.483    0.2640  ...                NaN             NaN
# 2009-08-05       1.102    0.9860  ...              223.0           194.0
# 2009-08-19       0.638    4.4360  ...              231.0           180.0
# 2009-09-02       0.744    0.2230  ...              237.0           171.0
# 2009-09-16       1.362    0.3040  ...              240.0           165.0
# 2009-10-02       8.720    0.3880  ...              239.0           173.0
# 2009-10-14       2.134    0.2870  ...              245.0           184.0
# 2009-10-27       2.329    0.4550  ...              253.0           196.0
# 2009-11-11       2.639    0.5260  ...              259.0           235.0
# 2009-11-25      24.860    0.6810  ...              271.0           196.0
# 2009-12-08       3.258    0.5410  ...              279.0           213.0
# ...

# %%
df.isna().sum()
# Out:
# phyto_biov            1
# zoo_biom              0
# zoo_chl               5
# crusta_lenght_mean    1
# crusta_nh4_mean       0
# crusta_nox_mean       0
# nutrient_frp          0
# nutrient_total_n      0
# nutrient_total_p      0
# nutrient_secchi       0
# nutrient_ph           1
# nutrient_mean         1
# conductivity_mean     1
# turbidity_mean        1
# dtype: int64

# %%
df.fillna(method='bfill', inplace=True)

# %%
df.isna().sum()
# Out:
# phyto_biov            0
# zoo_biom              0
# zoo_chl               0
# crusta_lenght_mean    0
# crusta_nh4_mean       0
# crusta_nox_mean       0
# nutrient_frp          0
# nutrient_total_n      0
# nutrient_total_p      0
# nutrient_secchi       0
# nutrient_ph           0
# nutrient_mean         0
# conductivity_mean     0
# turbidity_mean        0
# dtype: int64

# %% [markdown]
# # Кінцевий результат

# %%
df
# Out:
#             phyto_biov  zoo_biom  ...  conductivity_mean  turbidity_mean
# date                              ...
# 2009-07-21       1.483    0.2640  ...              223.0           194.0
# 2009-08-05       1.102    0.9860  ...              223.0           194.0
# 2009-08-19       0.638    4.4360  ...              231.0           180.0
# 2009-09-02       0.744    0.2230  ...              237.0           171.0
# 2009-09-16       1.362    0.3040  ...              240.0           165.0
# 2009-10-02       8.720    0.3880  ...              239.0           173.0
# 2009-10-14       2.134    0.2870  ...              245.0           184.0
# 2009-10-27       2.329    0.4550  ...              253.0           196.0
# 2009-11-11       2.639    0.5260  ...              259.0           235.0
# 2009-11-25      24.860    0.6810  ...              271.0           196.0
# 2009-12-08       3.258    0.5410  ...              279.0           213.0
# ...
